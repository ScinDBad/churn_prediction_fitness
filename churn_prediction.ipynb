# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Descripción" data-toc-modified-id="Descripción-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Descripción</strong></a></span></li><li><span><a href="#Análisis-Exploratorio-de-Datos-(EDA)" data-toc-modified-id="Análisis-Exploratorio-de-Datos-(EDA)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><strong>Análisis Exploratorio de Datos (EDA)</strong></a></span><ul class="toc-item"><li><span><a href="#Observación-preliminar-de-datos" data-toc-modified-id="Observación-preliminar-de-datos-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Observación preliminar de datos</a></span></li><li><span><a href="#Estadísticas-Descriptivas" data-toc-modified-id="Estadísticas-Descriptivas-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Estadísticas Descriptivas</a></span></li><li><span><a href="#Variable-Objetivo" data-toc-modified-id="Variable-Objetivo-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Variable Objetivo</a></span></li><li><span><a href="#Distribución-de-datos" data-toc-modified-id="Distribución-de-datos-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Distribución de datos</a></span></li><li><span><a href="#Pre-procesamiento" data-toc-modified-id="Pre-procesamiento-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Pre-procesamiento</a></span><ul class="toc-item"><li><span><a href="#Reemplazo-de-Outliers" data-toc-modified-id="Reemplazo-de-Outliers-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Reemplazo de Outliers</a></span></li></ul></li><li><span><a href="#Correlación-de-Características" data-toc-modified-id="Correlación-de-Características-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Correlación de Características</a></span></li></ul></li><li><span><a href="#Construcción-de-Modelo-predictivo" data-toc-modified-id="Construcción-de-Modelo-predictivo-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><strong>Construcción de Modelo predictivo</strong></a></span><ul class="toc-item"><li><span><a href="#Pre-Selección-de-Modelos" data-toc-modified-id="Pre-Selección-de-Modelos-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Pre-Selección de Modelos</a></span></li><li><span><a href="#Segmentación-de-datos" data-toc-modified-id="Segmentación-de-datos-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Segmentación de datos</a></span></li><li><span><a href="#Entrenamiento-y-Predicción" data-toc-modified-id="Entrenamiento-y-Predicción-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Entrenamiento y Predicción</a></span></li><li><span><a href="#Ajuste-de-Modelo" data-toc-modified-id="Ajuste-de-Modelo-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Ajuste de Modelo</a></span><ul class="toc-item"><li><span><a href="#Reducción-de-Dimensionalidad" data-toc-modified-id="Reducción-de-Dimensionalidad-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Reducción de Dimensionalidad</a></span></li><li><span><a href="#Primer-Reentrenamiento-y-Predicción" data-toc-modified-id="Primer-Reentrenamiento-y-Predicción-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Primer Reentrenamiento y Predicción</a></span></li><li><span><a href="#Ajuste-de-hiperparámetros" data-toc-modified-id="Ajuste-de-hiperparámetros-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Ajuste de hiperparámetros</a></span></li><li><span><a href="#Segundo-Reentrenamiento-y-Predicción" data-toc-modified-id="Segundo-Reentrenamiento-y-Predicción-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Segundo Reentrenamiento y Predicción</a></span></li></ul></li><li><span><a href="#Selección-del-modelo" data-toc-modified-id="Selección-del-modelo-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Selección del modelo</a></span></li></ul></li><li><span><a href="#Clustering-de-Usuarios" data-toc-modified-id="Clustering-de-Usuarios-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><strong>Clustering de Usuarios</strong></a></span><ul class="toc-item"><li><span><a href="#Dendograma" data-toc-modified-id="Dendograma-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Dendograma</a></span></li><li><span><a href="#Entrenamiento-y-Predicción-K-Means" data-toc-modified-id="Entrenamiento-y-Predicción-K-Means-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Entrenamiento y Predicción K-Means</a></span><ul class="toc-item"><li><span><a href="#Caracterización-de-Clústers" data-toc-modified-id="Caracterización-de-Clústers-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Caracterización de Clústers</a></span></li><li><span><a href="#Comparativa-de-clústeres" data-toc-modified-id="Comparativa-de-clústeres-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Comparativa de clústeres</a></span></li><li><span><a href="#Diagnóstico-de-deserción" data-toc-modified-id="Diagnóstico-de-deserción-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Diagnóstico de deserción</a></span></li><li><span><a href="#Perfil-de-usuario-desertor" data-toc-modified-id="Perfil-de-usuario-desertor-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Perfil de usuario desertor</a></span></li><li><span><a href="#Identificación-de-Necesidades" data-toc-modified-id="Identificación-de-Necesidades-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Identificación de Necesidades</a></span></li><li><span><a href="#Distribución-por-clúster" data-toc-modified-id="Distribución-por-clúster-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Distribución por clúster</a></span><ul class="toc-item"><li><span><a href="#Histogramas-por-clúster" data-toc-modified-id="Histogramas-por-clúster-4.2.6.1"><span class="toc-item-num">4.2.6.1&nbsp;&nbsp;</span>Histogramas por clúster</a></span></li></ul></li><li><span><a href="#Propuesta-Estratégica" data-toc-modified-id="Propuesta-Estratégica-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Propuesta Estratégica</a></span></li><li><span><a href="#Representación-de-Clústers" data-toc-modified-id="Representación-de-Clústers-4.2.8"><span class="toc-item-num">4.2.8&nbsp;&nbsp;</span>Representación de Clústers</a></span></li><li><span><a href="#Tasa-de-Cancelación" data-toc-modified-id="Tasa-de-Cancelación-4.2.9"><span class="toc-item-num">4.2.9&nbsp;&nbsp;</span>Tasa de Cancelación</a></span></li></ul></li></ul></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-5"><span class="toc-item-num">5&nbsp;&nbsp;</span><strong>Conclusiones</strong></a></span></li><li><span><a href="#Recomendaciones" data-toc-modified-id="Recomendaciones-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><strong>Recomendaciones</strong></a></span></li><li><span><a href="#Varios" data-toc-modified-id="Varios-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Varios</a></span></li></ul></div>

# %% [markdown]
# # 🔎 Análisis y Estrategias para la retención de clientes en Model Fitness 📈🏋🏻‍♀️
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## __Descripción__

# %% [markdown]
# Model Fitness es una cadena de gimnasios que tiene por objetivo implementar una estrategia efectiva de retención de clientes en Model Fitness mediante análisis de datos avanzado. El objetivo principal es predecir la probabilidad de pérdida de clientes para el próximo mes, identificar perfiles de clientes clave y desarrollar recomendaciones específicas para mejorar la retención y la satisfacción del cliente. Esta iniciativa tiene como meta optimizar la experiencia del cliente y fortalecer la fidelización en nuestra comunidad fitness.
#
# __Objetivos:__
# - Utilizar datos disponibles para prever la probabilidad de abandono de clientes.
#
#
# - Identificar grupos característicos de clientes para personalizar estrategias de retención.
#
#
# - Investigar qué factores (datos disponibles) influyen más en la pérdida de clientes.
#
#
# - Determinar medidas concretas para reducir la rotación de clientes y mejorar la satisfacción general.

# %%
import time
start_time1 = time.time()

# importación de librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, silhouette_score

from sklearn.model_selection import learning_curve
from sklearn.metrics import plot_confusion_matrix, plot_roc_curve

from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
from itertools import combinations

# %%
# Carga de datos
gym = pd.read_csv('/datasets/gym_churn_us.csv')

# %% [markdown]
# ## __Análisis Exploratorio de Datos (EDA)__
#
# - Observación preliminar de datos
# - Determinar variable objetivo
# - Observar valores medios de características
# - Visualizar distribución de las características
# - Trazar matriz de correlación

# %% [markdown]
# ### Observación preliminar de datos

# %%
gym.head() # vista preliminar del df
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
gym.info() # observar información general
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %%
gym.duplicated().sum() #averiguar existencia de duplicados
# Out:
# 0

# %% [markdown]
# No hay valores ausentes ni registros duplicados. Conviene que los nombres de columna sean minúsculas

# %%
gym = gym.rename(columns=lambda x: x.lower()) # Convertir nombres de columnas a minúsculas

# %% [markdown]
# ### Estadísticas Descriptivas

# %%
gym.describe().T.drop(['25%', '50%', '75%'], axis=1) # Obtener estadísticas descriptivas de los atributos
# Out:
#                                     count        mean        std        min  \
# gender                             4000.0    0.510250   0.499957   0.000000
# near_location                      4000.0    0.845250   0.361711   0.000000
# partner                            4000.0    0.486750   0.499887   0.000000
# promo_friends                      4000.0    0.308500   0.461932   0.000000
# phone                              4000.0    0.903500   0.295313   0.000000
# contract_period                    4000.0    4.681250   4.549706   1.000000
# group_visits                       4000.0    0.412250   0.492301   0.000000
# age                                4000.0   29.184250   3.258367  18.000000
# avg_additional_charges_total       4000.0  146.943728  96.355602   0.148205
# month_to_end_contract              4000.0    4.322750   4.191297   1.000000
# lifetime                           4000.0    3.724750   3.749267   0.000000
# ...

# %% [markdown]
# 6 características son binarias (0-1) y 7 características son continuas. Conviene realizar una estandarización para facilitar el modelado de la pronosticación de la variable objetivo 'churn'.
#
# Aunque la descripción de los requerimientos del cliente no lo especifica, se asumirá churn=0 como no cancelado y churn=1 como cancelado.

# %% [markdown]
# ### Variable Objetivo
#
# La variable objetivo corresponde a la columna 'churn' cancelación de los clientes que se pretende pronosticar para mejorar la retención de los mismos.

# %% [markdown]
# Aquellas características de distribución continua, dependiendo del sesgo, su mejor estimador será la media o mediana.

# %% [markdown]
# ### Distribución de datos

# %%
# función de trazado de histograma comparativo
def histplot(df, hue, alpha):
    # Número de filas para el subplot, calculado según el número de características y columnas
    num_rows = int(np.ceil(len(df.columns) / 4))

    # Crear una figura y un conjunto de subplots
    fig, axes = plt.subplots(num_rows, 4, figsize=(12, num_rows * 2))

    # Aplanar el array de axes para iterar fácilmente
    axes = axes.flatten()
    
    # Bucle para dibujar cada histograma en su respectivo subplot
    for i, feature in enumerate(df.columns):
        sns.histplot(data=df, x=feature, bins = 'auto', ax=axes[i], hue=hue, 
                     palette=['green', 'red'], alpha=alpha)

    # Ocultar los axes vacíos si los hay
    for ax in axes[len(df.columns):]:
        ax.set_visible(False)

    # Mostrar la figura con todos los subplots
    plt.tight_layout()
    plt.show()

# %%
histplot(gym, hue='churn', alpha=0.3) # histogramas de características de clientes que cancelan

# %% [markdown]
# Las características con distribuciones continuas y claramente identificables son la edad, frecuencia media de visitas, cantidad total de dinero gastado en servicios adicionales, el tiempo transcurrido desde que el cliente llegó al gym, el tiempo restante para expiración del contrato y la frecuencia media de visitas durante el mes. El resto de distribuciones son discretas. Parececría no haber valores atítpicos abundantes, pero eso se podrá corroborar con boxplots. A priori las variables que requieren gestión de valores atípicos son `'age'`, `'avg_additional_charges_total'`, `'lifetime'`, `'avg_class_frequency_total'`, `'avg_class_frequency_current_month'` debido a su continuidad y consistencia en su distribución.

# %%
# funcion de trazado de boxplots comparativos
def boxplot(df, hue):
    # Número de filas para el subplot, calculado según el número de características y columnas
    num_rows = int(np.ceil(len(df.columns) / 4))

    # Crear una figura y un conjunto de subplots
    fig, axes = plt.subplots(num_rows, 4, figsize=(12, num_rows * 2))

    # Aplanar el array de axes para iterar fácilmente
    axes = axes.flatten()
    
    # Bucle para dibujar cada boxplot en su respectivo subplot
    for i, feature in enumerate(df.columns):
        sns.boxplot(data=df, y=hue, x=feature, ax=axes[i], palette=['green', 'red'], orient='h')

    # Ocultar los axes vacíos si los hay
    for ax in axes[len(df.columns):]:
        ax.set_visible(False)

    # Mostrar la figura con todos los subplots
    plt.tight_layout()
    plt.show()

# %%
boxplot(gym, hue='churn') # distribución boxplot de características de clientes que cancelaron

# %% [markdown]
# Existen claramente datos atípicos en la mayoría de características, en algunas más que otras, concretamente son 17 de 28 distribuciones con valores atípicos. Eliminar algunos de estos valores en determinada característica incurre en riesgo de borrar registros donde un valor de característica no sea atípico y se provocarían sesgos notables y no desados.
#
# Una opción a considerar es el reemplazo de estos valores atípicos por la métrica de estimación de su correspondiente característica.
#
# Los reemplazos tentativos de outliers adecuados son los siguientes:
#
# __Media:__
#
# - `'age'` (debido a su patrón de distribución normal)
#
# __Mediana:__
#
# Debido al sesgo positivo
# - `'lifetime'`
# - `'avg_additional_charges_total'`
# - `'avg_class_frequency_total'`
# - `'avg_class_frequency_current_month'`

# %%
# función de trazado de dispersión de clientes que cancelan membresia de gym
def scatterplot(df, y, hue, alpha):
    # Número de filas para el subplot, calculado según el número de características y columnas
    num_rows = int(np.ceil(len(df.columns) / 4))

    # Crear una figura y un conjunto de subplots
    fig, axes = plt.subplots(num_rows, 4, figsize=(12, num_rows * 2.25))

    # Aplanar el array de axes para iterar fácilmente
    axes = axes.flatten()
    
    # Bucle para dibujar cada scatter en su respectivo subplot
    for i, feature in enumerate(df.columns):
        sns.scatterplot(data=df, x=feature, y=y, ax=axes[i], hue=hue, palette=['green', 'red'], alpha=alpha)

    # Ocultar los axes vacíos si los hay
    for ax in axes[len(df.columns):]:
        ax.set_visible(False)

    # Mostrar la figura con todos los subplots
    plt.tight_layout()
    plt.show()

# %%
scatterplot(gym, y='churn', hue='churn', alpha=0.3)

# %% [markdown]
# La primera mitad de los diagramas de dispersión parece tener solo 4 puntos pero realmente son muchos puntos superpuestos debido a la naturaleza de las características en cuestion que poseen dos valores discretos posibles y así mismo solo dos valores disccretos en la variable objetivo.
#
# A priori se revelan algunos datos visuales:
#
# - Los clientes que generalmente cancelan su suscripción son aquellos menores a 35 años.
# - Los clientes que generalmente se quedan son aquellos que adquieren servicios adicionales alrededor de los 500 usd.
# - Los clientes que suelen darse de baja son aquellos que les quedan 1 mes de contrato, 4-6 meses o 11-12 meses.
# - Los clientes empiezan a darse de al cumplir alrededor de 7 meses
# - Los clientes que permanecen generalmente llevan más de 7 meses.
# - Los clientes que se dan de baja por lo general realizaron menos 3.5 visitas semanales.
# - Los clientes que siguen activos generalmente realizan alrededor de 5 visitas mensuales y de forma casi constante.

# %% [markdown]
# ### Pre-procesamiento
#
# Los valores atípicos son abundantes en algunas características y en otras no. Según sea la distribución de las características se aplicará un determinado método de gestión de outliers.

# %%
# Función de agregación personalizada similar a .describe() con métricas de outliers para todas las columnas
def count_outliers(group):
    # Inicializar un diccionario para almacenar las estadísticas calculadas
    summary_stats = {}

    # Iterar sobre cada columna en el grupo
    for col in group.columns:
        values = group[col]
               
        # Calcular outliers usando el rango intercuartílico (IQR)
        q1 = np.percentile(values, 25)
        q3 = np.percentile(values, 75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        outliers = (values < lower_bound) | (values > upper_bound)
        num_outliers = outliers.sum()
        outlier_percentage = (num_outliers / values.count()) * 100 
        
        # Calcular percentil correspondiente a upper_bound
        upper_bound_percentile = stats.percentileofscore(values, upper_bound)

        # Almacenar las estadísticas en el diccionario
        summary_stats[col] = {
            'num_outliers': num_outliers,
            'outlier_%': outlier_percentage,
            'outlying_p()': upper_bound_percentile
        }

    # Convertir el diccionario en un DataFrame y retornar
    return pd.DataFrame(summary_stats)

# %%
outliers = gym.groupby('churn').apply(count_outliers).T.round(3) # mostrar cuantificación de outliers
outliers = outliers.head(-1)
display(outliers)

# Obtener la media, mediana, P5 y P95 de las características
gym_desc = gym.groupby('churn').agg({'mean', 'median', 'max',
                                     ('P5', lambda x: np.percentile(x, 5)),                                   
                                     ('P95', lambda x: np.percentile(x, 95)),
                                     }).T.unstack().round(2)

gym_desc
# Out:
# churn                                        0                         \
#                                   num_outliers outlier_% outlying_p()
# gender                                     0.0     0.000      100.000
# near_location                            373.0    12.691       56.363
# partner                                    0.0     0.000      100.000
# promo_friends                              0.0     0.000      100.000
# phone                                    283.0     9.629       54.832
# contract_period                            0.0     0.000      100.000
# group_visits                               0.0     0.000      100.000
# age                                       13.0     0.442       99.728
# avg_additional_charges_total              20.0     0.681       99.319
# month_to_end_contract                      0.0     0.000      100.000
# lifetime                                 139.0     4.729       94.386
# ...

# %% [markdown]
# Algunos valores atípicos que son proporcionalmente numerosos o relevantes según el boxplot:
#
# - Las variables `'near_location'`, `'promo_friends'`, `'phone'` solo tienen dos posibles valors (0 y 1), por lo que sus valores atípicos son importantes y no es conveniente reemplazarlos con la media porque vuelve ambiguo el comportamiento del usuario. Reemplazar con la mediana supone dejar una sola alternativa. Así que en estas variables los __outliers deben permanecer intactos.__
#
#
# - Las variables `'contract_period'` y `'month_to_end_contract'` no son binarias pero su naturaleza temporal indica información sensible sobre los usuarios. Además un reemplazo de outliers provocaría una alteración grande en el patrón de distribución. __Sus outliers deben conservarse.__
#
#
# - La variable `'lifetime'` podría tener reemplazos de outliers, pero también tiene su importancia por naturaleza de tiempo. En el caso de clientes que cancelan, las observaciones atípicas se encuentran a partir del percentil 91.8 lo que indica un 8.2% de datos que son outliers. El P95 corresponde a 3 meses y el boxplot muestra que ese 8.2% de datos son sucesivos hasta el valor de 9 meses, denotando una tendencia sin valores extremos raros.
#
#     En el caso de los usuarios que permanecen se observan características similres con un 4.7% de datos que son outlier. El P95 corresponde a 12 meses, los outliers se extienden de forma sucesiva hasta el valor de 31 meses, denotando una tendencia sin valores valores extremos raros.
#     reemplazarlos por la mediana recortaría la cola derecha pero manteniendo el sesgo, por lo que para mantener el sesgo positivo consistente conviene más reemplazar entre el 2-5% de los outliers más extremos por P50 en lugar del 8.2%. Es decir un reemplazo parcial. Un 5% podría reducir mucho la cola y el sesgo luce importante en este caso.
#
#     Para ser más conservador se recomienda mantener intactos el 97.5% de los datos y solo __reemplazar el 2.5% de los últimos datos por el valor de P50 para no afectar mucho la cola derecha y mantener un sesgo razonable.__
#
#
# - La variable `'avg_class_frequency_total'` tiene para ambos casos de clientes menos del 2% de los datos como atípicos, por lo que se puede prescindir del reemplazo o trasladar esa cantidad al P95 o P50(debido al sesgo positivo). La variable `' avg_class_frequency_current_month'` tiene la misma tendencia por lo que también se puede __reemplazar los outliers por P95 o P50.__
#
#
# - La variable `' avg_class_frequency_total'` tiene para ambos casos de clientes menos del 1% de datos como atípicos, su sesgo también es positivo por lo que se puede __reemplazar los outliers por P95 o P50.__
#
# - La variable `'age'` tiene una distribución pácticamente normal, sus outlier corresponden a menos del 0.5% de los datos, por lo que se pueden  __reemplazar por P95 o P50.__ Sin embargo hay que tener en cuenta que la edad es un factor
#
#
# El procesamiento de outliers queda de la siguiente manera:
#
# __Reemplazo con P95__
# - `'lifetime'` (Reemplazo parcial)
# - `'avg_additional_charges_total'`
# - `'avg_class_frequency_total'`
# - `'avg_class_frequency_current_month'`
#
# __Reemplazo con P50__
# - `'age'`

# %% [markdown]
# #### Reemplazo de Outliers

# %%
# Función para reemplazar outliers por el valor del percentil x de cada columna
def replace_outliers_with_percentile(df, features, percentile, p_upper_bound=None, obj=None, obj_value=None):
    # Copiar el DataFrame para no modificar el original
    df_cleaned = df.copy()
    mask = False  # Inicializar obj_mask con un valor por defecto
    
    # Iterar sobre cada columna característica del DataFrame
    for feature in features:
        # Calcular el percentil de la columna actual
        percentile_ = np.percentile(df_cleaned[feature], percentile)
        
        # Calcular los límites para identificar outliers
        q1 = np.percentile(df_cleaned[feature], 25)
        q3 = np.percentile(df_cleaned[feature], 75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        
        # Reemplazar outliers por el valor del percentil        
        if p_upper_bound:
            upper_bound = np.percentile(df_cleaned[feature], p_upper_bound)
        
        # Condicion de segmento objetivo
        if (obj and obj_value):
            mask = (df_cleaned[obj]==obj_value)
        else:
            mask = True
        
        # Reemplazo de outliers según percentil, IQR y segmento objetivo
        df_cleaned[feature] = np.where(
            np.logical_and(
                mask, 
                (df_cleaned[feature] < lower_bound) | (df_cleaned[feature] > upper_bound)
            ),
            percentile_,
            df_cleaned[feature]
        )
    
    return df_cleaned

# %%
churn_values = [0, 1]
gym_cleaned = gym

for churn_val in churn_values:
    # Reemplazo con P95
    gym_cleaned = replace_outliers_with_percentile(
        df=gym_cleaned, obj='churn', obj_value=churn_val,
        features=[
            'avg_additional_charges_total',
            'avg_class_frequency_total',
            'avg_class_frequency_current_month'
        ],
        percentile=95
    )  

    # Reemplazo parcial con P50
    gym_cleaned = replace_outliers_with_percentile(
        df=gym_cleaned, obj='churn', obj_value=churn_val,
        features=['lifetime'],
        percentile=50,
        p_upper_bound=97.5,
    )

    # Reemplazo con P50
    gym_cleaned = replace_outliers_with_percentile(
         df=gym_cleaned, obj='churn', obj_value=churn_val,
        features=['age'],
        percentile=50,
    )

# %%
# Verificar distribución de características preprocesadas.
boxplot(gym_cleaned, hue='churn') 
histplot(gym_cleaned, hue='churn', alpha=0.3)

# %% [markdown]
# Nótese que las distribución de las variable 'lifetime' tiene un sesgo menos acelerado y menor cantidad de valores atípicos, el resto de variables siguen con el mismo patrón de distribución pero con un mínimo recorte en las colas laterales. De modo que los outliers poco relevantes influirán menos en el pronóstico a modelar.

# %%
outliers_ = gym_cleaned.groupby('churn').apply(count_outliers).T.round(3) # mostrar cuantificación de outliers
outliers_ = outliers_.head(-1)
display(outliers_)

# Obtener la media, mediana, P5 y P95 de las características
gym_desc_ = gym_cleaned.groupby('churn').agg({'mean', 'median', 'max',
                                     ('P5', lambda x: np.percentile(x, 5)),                                   
                                     ('P95', lambda x: np.percentile(x, 95)),
                                     }).T.unstack().round(2)

gym_desc_
# Out:
# churn                                        0                         \
#                                   num_outliers outlier_% outlying_p()
# gender                                     0.0     0.000      100.000
# near_location                            373.0    12.691       56.363
# partner                                    0.0     0.000      100.000
# promo_friends                              0.0     0.000      100.000
# phone                                    283.0     9.629       54.832
# contract_period                            0.0     0.000      100.000
# group_visits                               0.0     0.000      100.000
# age                                        5.0     0.170      100.000
# avg_additional_charges_total               0.0     0.000      100.000
# month_to_end_contract                      0.0     0.000      100.000
# lifetime                                  52.0     1.769       97.346
# ...

# %% [markdown]
# ### Correlación de Características

# %%
plt.figure(figsize=(8, 8))  # Ajusta el tamaño de la figura según tus preferencias
sns.heatmap(gym_cleaned.corr(), annot=True, fmt=".2f", cbar = False)
plt.show()

# %% [markdown]
# En la matriz de características se encuentran dos pares de características altamente correlacionadas:
# - `corr(month_to_end_contract, contract_period) = 0.97`
# - `corr(avg_class_frequency_current_month y avg_class_frequency_total) = 0.95`
#
# De manera son características colineales y conviene gestionar su impacto en la variable objetivo, es decir eliminarlas.
#
# Las __características tentativas a ser eliminadas__ son las siguientes:
# -  __'contract_period'__ ya que es estática y no cambia durante la vida del contrato a diferencia de 'month_to_end_contract' que cambia su valor periodicamente al tratarse del tiempo restante hasta la expiración del contrato.
#
#
# -  __'avg_class_frequency_total'__ ya que es general a diferencia de 'Avg_class_frequency_current_month' que proporciona información específica y reciente que podría se más aprovechada para identificar cambios de comportamiento a corto plazo.

# %%
gym_cleaned = gym_cleaned.drop(['contract_period', 'avg_class_frequency_total'], axis = 1) # eliminar características
print(gym_cleaned.shape) # verificar eliminación de características.
# Out:
# (4000, 12)

# %%
# mostrar matriz de correlaciones nuevamente
plt.figure(figsize=(8, 8))  # Ajusta el tamaño de la figura según tus preferencias
sns.heatmap(gym_cleaned.corr(), annot=True, fmt=".2f", cbar = False)
plt.show()

# %% [markdown]
# ## __Construcción de Modelo predictivo__

# %% [markdown]
# ### Pre-Selección de Modelos
#
# Se procede a determinar el modelo apropiado para clasificación binaria. Las opciones posibles son:
# - Regresión Logística
# - Bosque Aleatorio

# %% [markdown]
# ### Segmentación de datos
#
# - Separar la matriz característica y el vector de variable objetivo
# - Estandarizar la matriz característica
# - Dividir datos de entrenamiento y prueba
# - Entrenar modelos de clasificación
# - Comparar métricas y seleccionar modelo

# %%
# divide los datos en características (la matriz X) y una variable objetivo (y)
X = gym_cleaned.drop('churn', axis = 1)
y = gym_cleaned['churn']

scaler = StandardScaler() # crear un objeto de clase scaler
scaler.fit(X) # entrenar el estandarizador

# divide los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
### Estandarizacion

# %%
# estandariza los datos
scaler = StandardScaler()
X_train_st = scaler.fit_transform(X_train) # estandariza el conjunto de entrenamiento 
X_test_st = scaler.transform(X_test) # estandariza el conjunto de prueba

# %% [markdown]
# ### Entrenamiento y Predicción

# %%
# Declarar modelos
seed = 42 # semilla para generación aleatoria
logr_model = LogisticRegression(random_state=seed)
rfc_model = RandomForestClassifier(random_state=seed)

def make_prediction(model, X_train, y_train, X_test, y_test):
    # Iniciar el temporizador para medir el tiempo de entrenamiento
    start_time = time.time()
    
    # Entrenar el modelo
    model.fit(X_train, y_train)
    
    # Calcular el tiempo de entrenamiento
    training_time = time.time() - start_time
    
    # Iniciar el temporizador para medir el tiempo de predicción
    start_time = time.time()
    
    # Hacer predicciones
    y_pred = model.predict(X_test)
    
    # Calcular el tiempo de predicción
    prediction_time = time.time() - start_time
    
    # Mostrar todas las métricas estudiadas para la predicción resultante
    print(model)
    print('Exactitud: {:.2f}'.format(accuracy_score(y_test, y_pred)))
    print('Precisión: {:.2f}'.format(precision_score(y_test, y_pred)))
    print('Recall: {:.2f}'.format(recall_score(y_test, y_pred)))
    
    print(f"\nTiempo de entrenamiento: {training_time:.2f} segundos")
    print(f"Tiempo de predicción: {prediction_time:.2f} segundos")

# %%
make_prediction(logr_model, X_train_st, y_train, X_test_st, y_test)
# Out:
# LogisticRegression(random_state=42)
# Exactitud: 0.91
# Precisión: 0.81
# Recall: 0.81
#
# Tiempo de entrenamiento: 0.07 segundos
# Tiempo de predicción: 0.00 segundos

# %% [markdown]
# El modelo presenta métricas bastante buenas, el modelo es 91% exacto, de las predicciones positivas identificó correctamente el 81% y de los positivos verdaderos el modelo acierta también un 81%.

# %%
make_prediction(rfc_model, X_train_st, y_train, X_test_st, y_test)
# Out:
# RandomForestClassifier(random_state=42)
# Exactitud: 0.90
# Precisión: 0.81
# Recall: 0.76
#
# Tiempo de entrenamiento: 0.56 segundos
# Tiempo de predicción: 0.03 segundos

# %% [markdown]
# El modelo de regresión logística obtuvo mejores resultados y además es más rápido que el bosque aleatorio.

# %%
# Función para graficar curvas de aprendizaje
def plot_learning_curve(estimator, X, y, model_name, score_reference):
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.figure(figsize=(11.5, 6))
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="b")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="b", label="Cross-validation score")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.title(f"Learning Curve ({model_name})")
    plt.axhline(y=score_reference, color='g', linestyle='--', label="Desired Score (0.91)")
    plt.legend()
    plt.show()

# %%
# Función para evaluar el modelo RandomForestClassifier
def evaluate_model_classifier(model, model_name, X_test, y_test):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4), gridspec_kw={'wspace': 0.5})  # Subplot de 1 fila y 2 columnas

    # Matriz de confusión
    disp_confusion = plot_confusion_matrix(model, X_test, y_test,
                                           cmap=plt.cm.Blues,
                                           normalize=None,
                                           ax=axes[0])
    disp_confusion.ax_.set_title(f'Confusion Matrix ({model_name})')

    # Curva ROC
    disp_roc = plot_roc_curve(model, X_test, y_test, ax=axes[1])
    disp_roc.ax_.set_title(f'ROC Curve ({model_name})')
    plt.show()

# %%
# Evaluar modelo
start_time = time.time()

plot_learning_curve(logr_model, X_train_st, y_train, 'Logistic Regression', 0.91)
evaluate_model_classifier(logr_model, 'Logistic Regression', X_test_st, y_test)

print(f'ejecución de evaluación: {time.time() - start_time:.2f} segundos')
# Out:
# ejecución de evaluación: 2.73 segundos

# %% [markdown]
# La curva de entrenamiento converge con la curva validación cruzada apartir de 1000 ejemplos de entrenamiento alcanzando un puntaje de 0.91 a los 2500 ejemplos. Parece un modelo bastante decente que se entrena y predice practicamente al instante con 4000 registros de caracteríticas con un test_size de 0.2.

# %% [markdown]
# El modelo de Regresión Logística resulta bueno debido a que la mayoría de predicciones son verderos negativos (563) y verdaderos positivos (161), además el area bajo la curva ROC es de 0.96 con una ligera mejora de calidad predictiva, además de una mejor cruva de aprendizaje. Este modelo tiende a predecir mejor a los clientes que permanecen que los que cancelan que en este caso son 563 clientes pronosticados leales y que verdaderamente permanecen suscritos.

# %%
# Evaluar el modelo (esperar 16 segundos)
start_time = time.time()

plot_learning_curve(rfc_model, X_train_st, y_train, 'Random Forest Classifier', 0.90)
evaluate_model_classifier(rfc_model, 'Random Forest Classifier', X_test_st, y_test)

print(f'ejecución de evaluación: {time.time() - start_time:.2f} segundos')
# Out:
# ejecución de evaluación: 17.23 segundos

# %% [markdown]
# La curva de entrenamiento muestra un comportamiento perfecto, el modelo indica estar sobreajustado. a demás le lleva más tiempo entrenarse, aunque su predicción es casi instantanea dado el conjunto de 4000 registros de datos segemntados en 20% para validación.

# %% [markdown]
# El modelo de Random Forest Classifier resulta bueno debido a que la mayoría de predicciones son verderos negativos (567) y verdaderos positivos (150), además el area bajo la curva ROC es de 0.95 pero esta sobreajustado debido a la curva de aprendizaje.
#
# Este modelo predice un poco mejor a los clientes que permanecen a costa de predecir un poco menos a los clientes que cancelan y aumentando un poco los falsos negativos. En ese aspecto su tendencia predictiva tecnicamente se mantiene.

# %% [markdown]
# En primera instancia debido a la naturaleza de los objetivos, el recall más alto es más adecuado para el objetivo específico de Model Fitnes para la retención de clientes en riesgo de cancelación, ya que identifica mejor a los que realmente cancelarán sus membresías. __Por lo que se recomienda el modelo de Regresión logística que tiene mejor recall(sensibilidad), por sencillez y eficiencia.__

# %% [markdown]
# __Nota:__ Se puede mejorar el modelo de bosque aleatorio con reducción de dimensionalidad y ajuste de hiperparámetros.

# %% [markdown]
# ### Ajuste de Modelo

# %% [markdown]
# - Reducción de dimensionalidad (importancia de características)
# - Primer reentrenamiento
# - Ajuste de hiperparámetros de bosque aleatorio
# - Segundo reentrenamiento

# %% [markdown]
# #### Reducción de Dimensionalidad

# %%
# crea un DataFrame con los nombres de las características y la importancia
fi_df = pd.DataFrame(data ={'feature': X.columns, 'importance': rfc_model.feature_importances_})
fi_df.sort_values('importance', ascending = False, inplace=True)
fi_df
# Out:
#                               feature  importance
# 9                            lifetime    0.308760
# 10  avg_class_frequency_current_month    0.223258
# 6                                 age    0.133724
# 7        avg_additional_charges_total    0.125505
# 8               month_to_end_contract    0.119588
# 5                        group_visits    0.020063
# 2                             partner    0.016120
# 0                              gender    0.015929
# 3                       promo_friends    0.015645
# 1                       near_location    0.013046
# 4                               phone    0.008363

# %% [markdown]
# Las características más importantes son 6, 7, 8, 9, 10. Se procede al correspondiente filtrado y subsiguiente entrenamiento

# %%
selected_features = fi_df['feature'].head(5) # seleccionar las características más influyentes
selected_features
# Out:
# 9                              lifetime
# 10    avg_class_frequency_current_month
# 6                                   age
# 7          avg_additional_charges_total
# 8                 month_to_end_contract
# Name: feature, dtype: object

# %% [markdown]
# #### Primer Reentrenamiento y Predicción

# %%
# Filtrar datos de entrenamiento y validación por las características más importantes
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

# Estandarizar conjuntos de entrenamiento y prueba
X_train_selected_st = scaler.fit_transform(X_train_selected) 
X_test_selected_st = scaler.transform(X_test_selected) 

# Entrenar modelo y Pronosticar 
make_prediction(rfc_model, X_train_selected_st, y_train, X_test_selected_st, y_test)
# Out:
# RandomForestClassifier(random_state=42)
# Exactitud: 0.90
# Precisión: 0.81
# Recall: 0.77
#
# Tiempo de entrenamiento: 0.52 segundos
# Tiempo de predicción: 0.03 segundos

# %% [markdown]
# El recall mejoró una centésima, sus métricas son técnicamente iguales. Se procede a verificar su curva de aprendizaje.

# %%
# Evaluar el modelo (esperar 16 segundos)
start_time = time.time() 

plot_learning_curve(rfc_model, X_train_selected_st, y_train, 'Random Forest Classifier', 0.90)
evaluate_model_classifier(rfc_model, 'Random Forest Classifier', X_test_selected_st, y_test)

print(f'ejecución de evaluación: {time.time() - start_time:.2f} segundos')
# Out:
# ejecución de evaluación: 18.84 segundos

# %% [markdown]
# El modelo sigue sobreajustado a pesar de haber reducido dimensionalidad y estandarizar los datos, por lo que se procede a ajustar los hiperparámetros. Su calidad y tendencia predictiva se mantiene similar.

# %% [markdown]
# #### Ajuste de hiperparámetros
#
# Se ajustará el número de estimadores, profundidad y muestras mínimas para división de nodos.

# %%
# Ajustar hiperparámetros (Se realizaron múltiples combinaciones hasta llegar a esta configuración)
tuned_rfc_model = RandomForestClassifier(
    random_state=42,      # elegir la misma semilla de aleatoriedad
    n_estimators=50,      # número de estimadores
    max_depth=200,        # profundidad máxima
    min_samples_split=165 # muestras mínimas para división de nodos
)

# %% [markdown]
# #### Segundo Reentrenamiento y Predicción

# %%
# Entrenar modelo y proosticar
make_prediction(tuned_rfc_model, X_train_selected_st, y_train, X_test_selected_st, y_test)

# Evaluar el modelo (esperar 8 segundos)
start_time = time.time()

plot_learning_curve(tuned_rfc_model, X_train_selected_st, y_train, 'Random Forest Classifier', 0.90)
evaluate_model_classifier(tuned_rfc_model, 'Random Forest Classifier', X_test_selected_st, y_test)

print(f'ejecución de evaluación: {time.time() - start_time:.2f} segundos')
# Out:
# RandomForestClassifier(max_depth=200, min_samples_split=165, n_estimators=50,
#                        random_state=42)
# Exactitud: 0.88
# Precisión: 0.79
# Recall: 0.67
#
# Tiempo de entrenamiento: 0.21 segundos
# Tiempo de predicción: 0.01 segundos
# ejecución de evaluación: 7.33 segundos

# %% [markdown]
# ### Selección del modelo

# %% [markdown]
# El modelo ya no está sobreajustado, su convergencia es incluso más temprana. Sus métricas bajaron, por lo que podría indicar un ligero subajuste respecto a las métricas iniciales pero ahora tiene mucha más capacidad de generalización lo cual es positivo. Sin embargo, a pesar de que la precisión y exactitud bajaron levemente, el recall bajó casi un 10%; es decir que el modelo ahora identifica un 10% menos correctamente a los clientes que cancelan realmente sus membresías.
#
# En vista de que la sensibilidad (recall) es crucial para el objetivo de Model Fitness, __en definitiva el modelo de regresión Logística sigue siendo la mejor opción.__
#
# _**Nota:** En este caso resultó mejor implementar un modelo más sencillo que predice muy buenos resultados que un modelo más complejo que requiere ajustar sus parámetros constantemente hasta obtener un mejor rendimiento que es menor al anterior._

# %% [markdown]
# ## __Clustering de Usuarios__
#
# - Estandarización de Datos
# - Crear Matriz de Distancias
# - Determinar número de clústeres
# - Trazar Dendograma
# - Entrenar modelo de clustering

# %%
# estandarización de los datos
sc = StandardScaler()
X_sc = sc.fit_transform(gym) # estandarizar el dataset original

linked = linkage(X_sc, method = 'ward')

# %% [markdown]
# ### Dendograma

# %%
# Trazar Dendograma (Esperar hasta 130 segundos)
start_time = time.time()

plt.figure(figsize=(15, 7))  
dendrogram(linked, orientation='top')
plt.title('Agrupación jerárquica para GYM')
plt.xticks([])  # Establecer el eje x como vacío para ocultar las etiquetas
plt.show()

print(f'Tiempo de ejecución: {time.time() - start_time:.2f} segundos')
# Out:
# Tiempo de ejecución: 8.55 segundos

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Etiquetas del eje x eliminadas
# </div>

# %% [markdown]
# El dendograma estima un total de 5 clústeres, siendo la ramificación marrón la más grande.

# %%
km = KMeans(n_clusters = 5) # establecer el número de clústeres en 5
labels = km.fit_predict(X_sc) # aplicar el algoritmo y formar un vector de clúster

# %%
# función para representar gráficos de características pareadas para los clústeres
def show_clusters_on_plot(df, x_name,y_name, cluster_name):
    plt.figure(figsize = (10,10))
    sns.scatterplot(df[x_name], df[y_name],
          hue = df[cluster_name], palette = 'Paired'
       )
    plt.title('{} vs {}'.format(x_name, y_name))
    plt.show()

# %% [markdown]
# ### Entrenamiento y Predicción K-Means

# %%
# define el modelo k_means
km = KMeans(n_clusters=5, random_state=42)
labels = km.fit_predict(X_sc) # predice los clústeres para las observaciones

gym['cluster_km'] = labels # asignar etiquetas a df

# %% [markdown]
# #### Caracterización de Clústers

# %%
# obtiene las estadísticas de los valores medios de las características por clúster
km_table_means = gym.groupby(['cluster_km']).mean()
km_table_means.round(2).T
# Out:
# cluster_km                              0       1       2       3       4
# gender                               0.48    0.50    0.55    0.52    0.51
# near_location                        0.83    0.94    0.84    0.87    0.76
# partner                              0.45    0.77    0.37    0.47    0.34
# promo_friends                        0.25    0.56    0.22    0.31    0.18
# phone                                1.00    1.00    1.00    0.00    1.00
# contract_period                      2.65   11.17    2.75    4.81    1.57
# group_visits                         0.38    0.56    0.44    0.43    0.26
# age                                 30.01   29.90   29.98   29.33   26.91
# avg_additional_charges_total       153.53  161.51  160.18  144.16  115.11
# month_to_end_contract                2.46   10.22    2.53    4.49    1.51
# lifetime                             4.67    4.70    4.59    3.95    0.98
# avg_class_frequency_total            1.18    2.01    2.93    1.86    1.45
# ...

# %%
gym.max() # maximos totales por característica
# Out:
# gender                                 1.000000
# near_location                          1.000000
# partner                                1.000000
# promo_friends                          1.000000
# phone                                  1.000000
# contract_period                       12.000000
# group_visits                           1.000000
# age                                   41.000000
# avg_additional_charges_total         552.590740
# month_to_end_contract                 12.000000
# lifetime                              31.000000
# avg_class_frequency_total              6.023668
# avg_class_frequency_current_month      6.146783
# churn                                  1.000000
# cluster_km                             4.000000
# dtype: float64

# %%
# Normalizamos los valores medios de cada característica por cluster en proporciones
# Respecto del conjunto global
        # km_table_max = gym.groupby(['cluster_km']).max()
        # km_nmeans = km_table_means.div(km_table_max).round(2).T.fillna(0)
original_index = km_table_means.T.index
km_nmeans = km_table_means.div(gym.max()).round(2).T.fillna(0).reindex(original_index)
km_nmeans # mostrar df
# Out:
# cluster_km                            0     1     2     3     4
# gender                             0.48  0.50  0.55  0.52  0.51
# near_location                      0.83  0.94  0.84  0.87  0.76
# partner                            0.45  0.77  0.37  0.47  0.34
# promo_friends                      0.25  0.56  0.22  0.31  0.18
# phone                              1.00  1.00  1.00  0.00  1.00
# contract_period                    0.22  0.93  0.23  0.40  0.13
# group_visits                       0.38  0.56  0.44  0.43  0.26
# age                                0.73  0.73  0.73  0.72  0.66
# avg_additional_charges_total       0.28  0.29  0.29  0.26  0.21
# month_to_end_contract              0.21  0.85  0.21  0.37  0.13
# lifetime                           0.15  0.15  0.15  0.13  0.03
# avg_class_frequency_total          0.20  0.33  0.49  0.31  0.24
# avg_class_frequency_current_month  0.19  0.33  0.48  0.28  0.17
# churn                              0.00  0.02  0.01  0.26  1.00

# %% [markdown]
# #### Comparativa de clústeres

# %%
# función de trazado de barplot comparativo
def barplot(df):
    # Número de filas para el subplot, calculado según el número de características y columnas
    num_rows = int(np.ceil(len(df.columns) / 3))

    # Crear una figura y un conjunto de subplots
    fig, axes = plt.subplots(num_rows, 3, figsize=(11, num_rows * 2))

    # Aplanar el array de axes para iterar fácilmente
    axes = axes.flatten()
    
    # Bucle para dibujar cada histograma en su respectivo subplot
    for i, column in enumerate(df.columns):
        sns.barplot(data=df, x=df.index, y=column, ax=axes[i], color='blue', alpha=0.3)
        axes[i].set_title(f'Mean Rate - Cluster {column}')
        axes[i].set_ylim(0,1)
        axes[i].set_ylabel('rate')
        axes[i].set_xlabel('features')
        axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90, ha='center')
        if i in [0,1]:
            axes[i].set_xlabel('')
            axes[i].set_xticklabels([])  # Ocultar las etiquetas del eje x
        if i in [1,2,4]:
            axes[i].set_ylabel('')

    # Ocultar los axes vacíos si los hay
    for ax in axes[len(df.columns):]:
        ax.set_visible(False)

    # Mostrar la figura con todos los subplots
    #plt.tight_layout()
    plt.show()

# %%
barplot(km_nmeans) # trazar barplot de caracteristicas normalizadas por cada cluster

# %% [markdown]
# Al observar los valores medios y barplots de las características para cada clúster, hay varias cosas que llaman la atención:
#
# El cluster 4 muestra que los usuarios cancelan su suscripción, mientras que el resto de clústeres muestra bajas tasas de cancelación, y el clúster 3 tiene una media de 0.26 dando a entender que en promedio el 26% de usuarios abandona el gym. Por tanto los clústeres 3 y 4 son aquellos a los que hay que prestar más atención al comportamiento de los usuarios.
#
# #### Diagnóstico de deserción
#
# - __cercanía:__ En cierta forma los usuarios con mayor tasa de abandono están menos cerca del gimnasio.
#
# - __Compañía asociada y promoción de amigos:__ Los usuarios qué más abandonan el gimnasio no trabajan en una compañia asociada al gym ni obtuvieron descuento por inscribir a algún amigo.
#
# - __Periodo de Contrato:__ Los usuarios que más cancelaron contrataron una membresia de 1.57 o 4.81 meses
#
# - __Sesiones Grupales:__ El paticipar poco de sesiones grupales parece desmotivar a los usuarios continuar en el gym.
#
# - __Edad:__ Los usuarios que más cancelan tienen en promedio 26.9 años, los mayores de 29 suelen quedarse.
#
# - __Servicios adicionales:__ Los usuarios desertores gastaron menos en productos y servicios adicionales del gym.
#
# - __Periodo restante:__ Los usuarios que más abandonaron fueron los que en promedio les quedaba mes y medio de membresía.
#
# - __Tiempo en el Gym:__ Los usuarios que más dejaron de ir al gym en promedio no llegaron al mes, es decir se retiraron antes de cumplir 30 días. Seguido de aquellos que no llegaron a los 4 meses.
#
# - __Frecuencia de asistencia:__ En general los usuarios menos motivados asistian difícilmente 2 veces por semana
#
#
# Características simplificadas:
#
# - __Tiempo en el Gym:__ Los usuarios que más dejaron de ir al gym en promedio no llegaron al mes, es decir se retiraron antes de cumplir 30 días. Seguido de aquellos que no llegaron a los 4 meses.
#
# - __Frecuencia de asistencia:__ En general los usuarios menos motivados asistian difícilmente 2 veces por semana
#
# - __Edad:__ Los usuarios que más cancelan tienen en promedio 26.9 años, los mayores de 29 suelen quedarse.
#
# - __Servicios adicionales:__ Los usuarios desertores gastaron menos en productos y servicios adicionales del gym.
#
# - __Periodo restante:__ Los usuarios que más abandonaron fueron los que en promedio les quedaba mes y medio de membresía.
#
# #### Perfil de usuario desertor
#
# Según las características más relevantes el usuario que cancela su suscripción en el gimnasio es mayoritariamente joven de 26.9 años que no realiza muchos gastos adicionales, no asiste más 2 veces por semana y suele retirarse al mes faltándole 45 días de memebresía.

# %% [markdown]
# #### Identificación de Necesidades
#
# - __Sentido de Comunidad a Través de Sesiones Grupales:__
#     Las personas valoran sentirse parte de un grupo y buscan superar las barreras de distancia y motivación al asistir regularmente a sesiones grupales. Esto refuerza su compromiso y aumenta la probabilidad de participación continua.
#
#
# - __Horarios flexibles de Entrenamiento:__
#     Es fundamental conocer el horario más conveniente para los usuarios, facilitando así su asistencia y compromiso con las rutinas de entrenamiento. Esta adaptación mejora la experiencia general del usuario y reduce las barreras de participación.
#
#
# - __Acceso Equitativo a Descuentos y Promociones:__
#     Los usuarios más jóvenes no siempre están empleados por lo que valoran ofertas inclusivas que no dependan de afiliaciones específicas o referencias. Esto permite que más usuarios se beneficien de incentivos económicos y se sientan valorados como clientes.
#
#
# - __Compromiso por pago de membresías extendidas:__
#     Los usuarios tienden a comprometerse más cuando pagan una membresía que no es corta, ya que el pago de varios meses los insta a darle uso para no desperdiciar su dinero, de modo que se fomenta la permanencia y el hábito de ejercitarse por períodos más largos.
#
#
# - __Entrenamiento diferenciado para jóvenes:__
#     Los usuarios más jóvenes pueden necesitar estímulos adicionales para comprometerse con el entrenamiento regular, como sesiones desafiantes y asesorías especializadas que les permita descubrir los beneficios del entrenamiento continuo.
#
#
# - __Sistema de recompensas graduales:__
#     Los incentivos progresivos en servicios y productos internos motiva especialmente a los usuarios a prolongar su membresía. Esto fortalece su relación con el gimnasio y mejora su experiencia general. Se fideliza al ver su compromiso recompensado.

# %% [markdown]
# Si se desea simplificar las estrategias considerar entonces solo las características más importantes obtenidas previamente en la reducción de dimensionalidad

# %%
selected_features_ = list(selected_features) + ['churn']
selected_features_
barplot(km_nmeans.loc[selected_features_]) # trazar barplot por  cluster

# %% [markdown]
# #### Distribución por clúster

# %% [markdown]
# Para facilitar el análisis se puede tomar las características más importantes por reducción de dimensionalidad.

# %%
display(fi_df) # mostrar nuevamente importancia de características
selected_features_
# Out:
#                               feature  importance
# 9                            lifetime    0.308760
# 10  avg_class_frequency_current_month    0.223258
# 6                                 age    0.133724
# 7        avg_additional_charges_total    0.125505
# 8               month_to_end_contract    0.119588
# 5                        group_visits    0.020063
# 2                             partner    0.016120
# 0                              gender    0.015929
# 3                       promo_friends    0.015645
# 1                       near_location    0.013046
# 4                               phone    0.008363
# ['lifetime',
#  'avg_class_frequency_current_month',
#  'age',
#  'avg_additional_charges_total',
#  'month_to_end_contract',
#  'churn']

# %% [markdown]
# ##### Histogramas por clúster
#
# Ya se mencionó previamente como influyen las características en la cancelación de los usuarios, pero con las distribuciones se puede observar la particularidad de cada una. Se analizarán las características más importantes.

# %%
# histogramas de características por clúster de clientes que cancelan
k = 0
k_gym = gym[gym['cluster_km']==k][selected_features_]
histplot(k_gym, hue='churn', alpha=0.3) 
print(k_gym.agg({'mean','median'}).round(2))
print(f'Distribución de Características en Cluster {k}')
# Out:
#         lifetime  avg_class_frequency_current_month    age  \
# median      4.00                               1.27  30.00
# mean        4.67                               1.18  30.01
#
#         avg_additional_charges_total  month_to_end_contract  churn
# median                        145.50                   1.00    0.0
# mean                          153.53                   2.46    0.0
# Distribución de Características en Cluster 0

# %% [markdown]
# __CLuster 0:__
# - La mitad de usuarios tiene menos de 4 meses en el gym.
#
# - La mitad de usuarios acude al gym como mucho 1-2 veces por semana. La otra mitad menos de 1.27 veces.
#
# - Normalmente los usuarios tienen en promedio 30 años, siendo este el umbral que los divide en dos grupos.
#
# - Con sesgo positivo, la mitad de los usuarios realiza compras internas de hasta $145.50
#
# - A poco más de la mitad de los usuarios les quedan menos de 2.5 meses (10 semanas) de membresía
#
# - Ningún usuario ha abandonado el GYM.

# %%
k = 1
k_gym = gym[gym['cluster_km']==k][selected_features_]
histplot(k_gym, hue='churn', alpha=0.3) 
print(k_gym.agg({'mean','median'}).round(2))
print(f'Distribución de Características en Cluster {k}')
# Out:
#         lifetime  avg_class_frequency_current_month   age  \
# median       4.0                               2.06  30.0
# mean         4.7                               2.00  29.9
#
#         avg_additional_charges_total  month_to_end_contract  churn
# median                        156.70                  11.00   0.00
# mean                          161.51                  10.22   0.02
# Distribución de Características en Cluster 1

# %% [markdown]
# __CLuster 1:__
# - La mitad de usuarios tiene menos de 4 meses en el gym.
#
# - Los usuarios acuden al gym en promedio 2 de 4 veces por semana.
#
# - Normalmente los usuarios tienen en promedio 30 años.
#
# - Con sesgo positivo, la mitad de los usuarios realiza compras internas de hasta $156.70
#
# - A poco más de la mitad de los usuarios aun les quedan de 10-12 meses de membresía
#
# - Solo el 2% ha abandonado el GYM.

# %%
k = 2
k_gym = gym[gym['cluster_km']==k][selected_features_]
histplot(k_gym, hue='churn', alpha=0.3) 
print(k_gym.agg({'mean','median'}).round(2))
print(f'Distribución de Características en Cluster {k}')
# Out:
#         lifetime  avg_class_frequency_current_month    age  \
# median      4.00                               2.83  30.00
# mean        4.59                               2.94  29.98
#
#         avg_additional_charges_total  month_to_end_contract  churn
# median                        148.43                   1.00   0.00
# mean                          160.18                   2.53   0.01
# Distribución de Características en Cluster 2

# %% [markdown]
# __CLuster 2:__
# - La mitad de usuarios tiene menos de 4 meses en el gym.
#
# - Los mitad de usuarios acuden al gym de 3-6 veces por semana.
#
# - Normalmente los usuarios tienen en promedio 30 años.
#
# - La mitad de los usuarios realiza compras internas de hasta $156.70
#
# - A la mitad de los usuarios les queda a lo mucho 1 mes de membresía y a menos de la mitad alrededor de 6 meses.
#
# - Solo el 1% ha abandonado el GYM.

# %%
k = 3
k_gym = gym[gym['cluster_km']==k][selected_features_]
histplot(k_gym, hue='churn', alpha=0.3) 
print(k_gym['churn'].agg({'mean','median'}).round(2))
display(pd.DataFrame(k_gym.groupby('churn').agg({'mean','median'}).round(2)).T)
print(f'Distribución de Características en Cluster {k}')
# Out:
# median    0.00
# mean      0.26
# Name: churn, dtype: float64
# churn                                          0       1
# lifetime                          median    4.00    1.00
#                                   mean      5.01    0.97
# avg_class_frequency_current_month median    2.01    1.02
#                                   mean      1.96    1.07
# age                               median   30.00   27.00
#                                   mean     30.09   27.22
# avg_additional_charges_total      median  150.77  101.45
#                                   mean    156.76  108.98
# month_to_end_contract             median    6.00    1.00
#                                   mean      5.47    1.77
# Distribución de Características en Cluster 3

# %% [markdown]
# __CLuster 3:__
#
# - El 26% de los usuarios abandonó el GYM.
#
# - La mitad de usuarios consistentes asistió menos de 4 meses en el gym. Los desertores 1 mes,
#
# - Los usuarios más disciplinados acuden al gym alrededor de 2 veces por semana. Desertores 1 mes.
#
# - Normalmente los usuarios comprometidos tienen en promedio 30 años. Desertores 27.
#
# - La mitad de los usuarios asiduos realiza compras internas de hasta $150.77 y los desertores 101.45 usd.
#
# - A la mayoría de usuarios fieles les queda alrededor de 12 meses, 6 o menos de 2.5 meses de membresía. A la mitad de desertores como mucho un mes.

# %%
k = 4
k_gym = gym[gym['cluster_km']==k][selected_features_]
histplot(k_gym, hue='churn', alpha=0.3) 
print(k_gym.agg({'mean','median'}).round(2))
print(f'Distribución de Características en Cluster {k}')
# Out:
#         lifetime  avg_class_frequency_current_month    age  \
# median      1.00                               0.95  27.00
# mean        0.98                               1.03  26.91
#
#         avg_additional_charges_total  month_to_end_contract  churn
# median                        104.37                   1.00    1.0
# mean                          115.11                   1.51    1.0
# Distribución de Características en Cluster 4

# %% [markdown]
# __CLuster 4:__
#
# - Todos los usuarios abandonaron el GYM.
#
# - La mitad de usuarios se fueron al primer 1 mes.
#
# - La mitad de los usuarios conseguía acudir al gym 1 vez a la semana casi siempre.
#
# - Normalmente los usuarios tienen 27 años.
#
# - La mitad de los desertores realizó compras internas de hasta $104.37
#
# - Al 50%  de desertores le quedaba 6 semanas cuando se marcharon.

# %% [markdown]
# #### Propuesta Estratégica
#
# Prestar especial atención a los clientes de aproximadamente 27 años, darles un plan de entrenamiento atractivo con monitoreo semanal para motivarlos a entrenar más regularmente, promocionar membresías de 4-6 meses con plan de nutrición o kit de fidelización (indumentaria, accesorios, etc.)

# %% [markdown]
# #### Representación de Clústers

# %% [markdown]
# Se requiere representar los clústers por características pareadas, para ello se utilizarán las características más representativas del dataset y son 5 las características sin incluir la variable objetivo 'churn'

# %%
pd.Series(selected_features_) # mostrar las características más relevantes
# Out:
# 0                             lifetime
# 1    avg_class_frequency_current_month
# 2                                  age
# 3         avg_additional_charges_total
# 4                month_to_end_contract
# 5                                churn
# dtype: object

# %% [markdown]
# Se describen las combinaciones pareadas posibles y cómo se relacionan:
#
# 1. **lifetime vs. avg_class_frequency_current_month:**
# Relación entre la duración de la membresía y la frecuencia media de asistencia a clases en el mes actual.
#
#
# 2. **lifetime vs. age:**
# Relación entre la duración de la membresía y la edad de los clientes.
#
#
# 3. **lifetime vs. avg_additional_charges_total:**
# Relación entre la duración de la membresía y el total de gastos adicionales realizados.
#
#
# 4. **lifetime vs. month_to_end_contract:**
# Relación entre la duración de la membresía y el tiempo restante en el contrato.
#
#
# 5. **lifetime vs. churn:**
# Cómo la duración de la membresía influye en la cancelación.
#
# -------------------------------------------------------
#
# 6. **avg_class_frequency_current_month vs. age:**
# Relación entre la frecuencia media de asistencia a clases y la edad de los clientes.
#
#
# 7. **avg_class_frequency_current_month vs. avg_additional_charges_total:**
# Relación entre la frecuencia media de asistencia a clases y el total de gastos adicionales realizados.
#
#
# 8. **avg_class_frequency_current_month vs. month_to_end_contract:**
# Relación entre la frecuencia media de asistencia a clases y el tiempo restante en el contrato.
#
#
# 9. **avg_class_frequency_current_month vs. churn:**
# Cómo la frecuencia media de asistencia influye en la cancelación de usuarios.
#
# -------------------------------------------------------
# 10. **age vs. avg_additional_charges_total:**
# Relación entre la edad de los clientes y el total de gastos adicionales realizados.
#
#
# 11. **age vs. month_to_end_contract:**
# Relación entre la edad de los clientes y el tiempo restante en el contrato.
#
#
# 12. **age vs. churn:**
# Cómo la edad de los clientes influye en su cancelación de mebresía.
#
# -------------------------------------------------------
# 13. **vs. month_to_end_contract:**
# Relación entre el total de gastos adicionales realizados y el tiempo restante en el contrato.
#
#
# 14. **vs. churn:**
# Relación entre el total de gastos adicionales realizados y la cancelación de membresía.
#
#
# 15. **month_to_end_contract vs. churn:**
# Cómo el tiempo restante en el contrato influye en la cancelación de membresía.

# %% [markdown]
# Se procede a trazar los clústeres por par de características.

# %%
# Definir función de trazado básico de clústeres por par-características
def show_clusters_on_plot(df, x_name, y_name, cluster_name, ax):
    sns.scatterplot(x=df[x_name], y=df[y_name], hue=df[cluster_name], palette='Paired', ax=ax)
    ax.set_title(f'Clustering scatter')

# Definir función para agrupar gráficas de clústers por par-características
def plot_clusters_subplots(df, feature_combinations, cluster_name, figsize=(13.5, 4.5)):
    num_plots = len(feature_combinations)
    num_cols = min(num_plots, 3)  # Limitar el número de columnas a 3 para visualizar hasta 3 gráficos por fila
    num_rows = (num_plots // num_cols) + (1 if num_plots % num_cols != 0 else 0)  # Calcular el número de filas necesarias
    
    fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
    axes = axes.flatten()  # Aplanar el array de axes para iterar fácilmente
    
    for i, (x_name, y_name) in enumerate(feature_combinations):
        if i < len(axes):  # Solo graficar si hay un subplot disponible
            show_clusters_on_plot(df, x_name, y_name, cluster_name, ax=axes[i])
        else:
            break  # Detener el bucle si no hay más subplots disponibles
    
    # Ocultar los axes vacíos si los hay
    for ax in axes[num_plots:]:
        ax.set_visible(False)
    
    plt.tight_layout()  # Ajustar el espacio entre subplots
    plt.show()

# %%
# Obtener todas las combinaciones por pares
feature_combinations = list(combinations(selected_features_, 2))
gym_km = gym[list(selected_features_) + ['cluster_km']]
    
# trazar subplot
plot_clusters_subplots(gym_km, feature_combinations[:3], 'cluster_km')

# %% [markdown]
# - La antigüedad de los usuarios y su asistencia semanal al gym son relativamente distintivos en los clústees 0, 2 y 4. El resto de grupos son más ambiguos de clasificar (se superponen entre sí).
#
# - La antiguedad de los usuarios y su edad no son disitintivas entre los clústeres 0,1,2,3 pero el clúster 4 se diferencia cláramente del resto.
#
# - La antigüedad y los gastos adicionales tampoco parecen ser clave para distinguir a los usuarios de los clústeres 0,1,2,3 pero el 4 se diferencia cláramente del resto.

# %%
plot_clusters_subplots(gym_km, feature_combinations[3:6], 'cluster_km')

# %% [markdown]
# - La antigüedad y el tiempo restante de membresía son relativamente distintivos en los clústeres 0, 1, 4 , también lo son entre los clústeres 1, 2, 4.  El 4 se diferencia cláramente del resto.
#
# - La antiguedad es muy clara respecto al abandono, el clúster 4 se diferencia muy bien del resto que se superpone o intersecta. Particularmente se observa cancelación en los usuarios que tienen menos de 10 meses.
#
# - La asistencia semanal es diferenciable de la edad de los usuarios que pertenencen a los clústeres 0, 2 y 4.

# %%
plot_clusters_subplots(gym_km, feature_combinations[6:9], 'cluster_km')

# %% [markdown]
# - La asistencia semanal y los gastos adicionales diferencian relativamente bien a los usuarios de los clústeres 0,2 y del 2 con el 4.
#
# - La asistencia semanal y el tiempo restante de contracto distinguen a los usuarios del clúster 2 con el resto pero no entre el resto, es decir son diferenciables (k0, k1); (k0, k2); (k1, k2); (k1, k4); (k2, k4).
#
# - El abandono es claro respecto al asistencia semanal de los usuarios. Los desertores asistieron menos de 4 veces a la semana.

# %%
plot_clusters_subplots(gym_km, feature_combinations[9:12], 'cluster_km')

# %% [markdown]
# - La edad no determina claramente los gastos de los usuarios de los clústeres (0,1,2,3) pero si es más distinguible en el clúster 4 que son usuaris de 20-30 años que consumen generalmente menos de 150 usd.
#
# - La edad y el tiempo restante de membresía es más disitintivo en los clústeres 1 y 4.
#
# - El abandono es claro respecto a la edad en el clúster 4 (menos de 36 años), solo unos pocos jóvenes menores de 21 años permanecieron en el gym. El resto no se distingue claramente.

# %%
plot_clusters_subplots(gym_km, feature_combinations[12:15], 'cluster_km')

# %% [markdown]
# - Los gastos adicionales y el tiempo restande de membresía es distintivo en el clúster 1 respecto al resto que se superponen. Estos usuarios del k1 generalmente dejan de hacer gastos internos en el gym cuando les quedan menos de 5 meses de membresía.
#
# - El abandono es claro respecto a los gastos adicionales. Los usuarios del k4 gastaron en su mayoría hasta alrededor de 350 usd. El resto de usuarios de los otros grupos no tienen un patrón de gastos claro.
#
# - La cancelación de membresía suele ser clara respecto al tiempo restante en el clúster 4 donde los usuarios se retiraron cuando les quedaba menos de 7 meses. El resto de clústeres no son distinguibles en ese aspecto.

# %% [markdown]
# En síntesis el grupo cláramente distinguible es el clúster 4, que representa a usuarios casi en su totalidad desertores, es decir un grupo falto de compromiso con el entrenamiento. Será óptimo seguir las directrices propuestas.

# %% [markdown]
# #### Tasa de Cancelación

# %% [markdown]
# Se procede a calcular la proporción en la que cancelan los usuarios de cada cluster.

# %%
# Calculo de tasa de abandano de usuarios del gimnasio
gym.groupby('cluster_km')['churn'].mean().round(4).sort_values(ascending=False) * 100
# Out:
# cluster_km
# 4    99.79
# 3    26.37
# 1     1.55
# 2     0.71
# 0     0.12
# Name: churn, dtype: float64

# %% [markdown]
# __Nota:__ Dado que los valores posibles de 'churn' son 1 y 0 el promedio de los valores de 1 representa particularmente también la tasa de abandono; esto porque el sumar los 1 equivale a contarlos. __Pero vamos a demostrarlo__, procederemos a realizar el conteo correspondiente.

# %%
k_churn = gym.groupby('cluster_km')['churn'].agg({'count', 'sum'})
k_churn['churn_%'] = (k_churn['sum'] / k_churn['count'] * 100).round(2)
k_churn['mean'] = gym.groupby('cluster_km')['churn'].mean().round(4) * 100
k_churn.sort_values('mean', ascending=False)
# Out:
#             sum  count  churn_%   mean
# cluster_km
# 4           938    940    99.79  99.79
# 3           101    383    26.37  26.37
# 1            15    966     1.55   1.55
# 2             6    849     0.71   0.71
# 0             1    862     0.12   0.12

# %% [markdown]
# Previamente en el trazado de histogramas en la distribución de clústeres, ya se había obtenido la media pero por el redondeo aplicado y sin multiplicar por 100 se perdió precisión. Ahora en el dataframe reciente se puede apreciar exactamente la tasa de cancelación de los clientes de cada clúster:
#
# - El __0.12%__ de los usuarios del __cluster 0__ cancelaron sus membresías
# - El __1.55%__ de los usuarios del __cluster 1__ cancelaron sus membresías
# - El __0.71%__ de los usuarios del __cluster 2__ cancelaron sus membresías
# - El __26.37%__ de los usuarios del __cluster 3__ cancelaron sus membresías
# - El __99.79%__ de los usuarios del __cluster 4__ cancelaron sus membresías
#
# Por lo tanto el quinto grupo es el más propenso a retirarse, por no decir en su totalidad; en segundo lugar el cuarto grupo (cluster 3) donde 26 de cada 100 usuarios abandonan el gym. En el resto de grupos por cada 100 usuarios menos de 2 de ellos cancelan sus membresías.

# %% [markdown]
# ## __Conclusiones__

# %% [markdown]
# - Los usuarios fueron clasificados en 5 grupos de los cuáles el clúster 4 resultó estar conformado por puros usuarios que abandonaron el Gym generalmente jovenes que no pasaron de los 10 meses de asistencia. El clúster 3 tuvo apróximadamente una cuarta parte de usuarios que desertaron del gym.
#
# - Los usuarios más fieles por excelencia fueron los de los clústeres 0 y 2.
#
# - Los usuarios se caracterizaron por 13 aspectos, de los que los más influyentes respecto a la cancelación de membresía fueron:
#         - 'lifetime' (antigüedad)
#         - 'avg_class_frequency_current_month' (asistencia semanal en el mes)
#         - 'age'   (Edad)
#         - 'avg_additional_charges_total' (cargos adicionales)
#         - tiempo restante
#
# - La cancelación de membresías clasificada como __Churn = 1: abandono, 0: permanencia__, puede ser pronosticada mediante un algoritmo de aprendizaje supervisado de clasificación binaria denomindado __Regresión logística__ con un rendimiento bueno y capacidad discriminatoria notable, rápido de entrenar sin necesidad de ajustar sus hiperparámetros.
#
#     El modelo tiene gran capacidad de predecir `verdaderos negativos` es decir identificar mejor a los clientes que permanecen que los que cancelan según la matriz de confusión. Las métricas de predicción fueron:
#
#
#     - Exactitud: 0.91
#     - Precisión: 0.81
#     - Sensibilidad(Recall): 0.81
#     - Calidad (AUC-ROC): 0.96
#
# ![image.png](attachment:image.png)
#
#
# - El usuario que cancela su suscripción en el gimnasio es mayoritariamente joven de 26.9 años que no realiza muchos gastos adicionales, no asiste más 2 veces por semana y suele retirarse al mes faltándole 45 días de memebresía.

# %% [markdown]
# ## __Recomendaciones__

# %% [markdown]
# - La estrategia del gimnasio puede enfocarse en identificar a los nuevos clientes que serán constantes y planificar una estrategia de fidelización para minimizar la tasa de cancelación y las intenciones de abandono incluso en los usuarios medianamente constantes.
#
#
# - Prestar especial atención a los clientes de aproximadamente 27 años, darles un plan de entrenamiento atractivo con monitoreo semanal para motivarlos a entrenar más regularmente, promocionar membresías de 4-6 meses con plan de nutrición o kit de fidelización (indumentaria, accesorios, etc.)
#
#
# - Considerar promover:
#
#         a. Sentido de Comunidad a Través de Sesiones Grupales
#         b. Horarios flexibles de Entrenamiento
#         c. Acceso Equitativo a Descuentos y Promociones
#         d. Compromiso por pago de membresías extendidas
#         e. Entrenamiento diferenciado para jóvenes
#         f. Sistema de recompensas graduales
#
#   como parte de la estrategia de fidelización de clientes para extender la permanencia del usuario en el Gym
#
# - Evaluar el modelo predictivo de cancelación de membresías periodicamente, quincenal o mensualmente dependiendo del flujo de clientes nuevos y monitorear su rendimiento (métricas). Por ejemplo si el recall baja de 0.81 a 0.78 entonces considerar un nuevo ajuste y entrenamiento.
#
#
# - Si paulatinamente se agregan más servicios o características clave en la base de datos, esperar hasta tener un número significativo de usuarios para realizar un nuevo modelado y entrenamiento con el mismo y otros algortimos dependiendo de la complejidad de la base de datos y necesidades de Model Fitness.
#
#
# - Considerar presentar un Dashboard que visualice la tasa de cancelación, la identificación de clústeres y la distribución de sus características para que la administración monitoree el comportamiento de sus usuarios y planifique estrategias de fidelización o contingencia según el caso.

# %% [markdown]
# ## Varios

# %%
# Mostrar tiempo de ejecución del proyecto.
print(f'Tiempo de ejecución del proyecto: {time.time() - start_time1:.2f} segundos')
# Out:
# Tiempo de ejecución: 106.08 segundos
